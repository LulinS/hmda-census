# %%
import pandas as pd

# %%
values = []
for i in range(1990, 2022):
    df=pd.read_csv(f'../output/census_data_extract_{i}.csv', nrows=2, dtype=object)
    values.append(df)
df = pd.concat(values, axis=0)

# %%
df.head()
# Out:
#    activity_year  msa_md  state_code  county_code  census_tract  \
# 0           1990      40          48          441         10100
# 1           1990      40          48          441         10200
# 0           1991      40          48          441         10100
# 1           1991      40          48          441         10200
# 0           1992      40          48          441         10100
#
#    ffiec_msa_md_median_family_income  tract_population  \
# 0                              18036              5150
# 1                              18036              3289
# 0                              29900              5150
# 1                              29900              3289
# 0                              30600              5095
#
#    tract_minority_population_percent  tract_owner_occupied_units  \
# 0                               5.65                         659
# 1                              23.17                         556
# ...
